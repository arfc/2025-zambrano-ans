# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("EPS_data_nuclear.csv", index_col='index')
df
# Out:
#             eps
# index
# 2      0.106899
# 3      0.018301
# 4      0.062640
# 5      0.159850
# 6      0.067317
# ...         ...
# 75     0.007444
# 76     0.007518
# 77     0.007378
# 78     0.007717
# 79     0.002816
#
# [78 rows x 1 columns]

# %%
#plotting the associated eps values against number of runs
ax = df.plot()
ax.minorticks_on()
ax.grid(which='both')

# %%
#rolling mean on data to see changes between a specific generation and the preceding generation
ax = df.rolling(20).mean().plot()
ax.axhline(y=0.05, color='r', linestyle='--')

# %%
#to get accurate results, need to set the tolerance between 0.03 and 0.02 for accurate convergence
#could also set it to be 0.015
